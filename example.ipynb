# %%
import pandas as pd
import matplotlib.pyplot as plt
from pipeline import pipeline

server_data = pd.read_csv('./resampled/DEVELOP.csv')
times, anomalies = pipeline(server_data)

# %%
plt.scatter(times, anomalies)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 plt.scatter(times, anomalies)
# ----> 2 plt.xticks(100, 1)
#
# File ~/Documents/GitHub/DSC-Datathon/lib/python3.10/site-packages/matplotlib/pyplot.py:1886, in xticks(ticks, labels, minor, **kwargs)
#    1883         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    1884                         "without setting 'ticks'")
#    1885 else:
# -> 1886     locs = ax.set_xticks(ticks, minor=minor)
#    1888 if labels is None:
#    1889     labels = ax.get_xticklabels(minor=minor)
#
# File ~/Documents/GitHub/DSC-Datathon/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# ...
