# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
from read_json import read_json  # for json files

# %%
# crop data
import dask.dataframe as dd
data = dd.read_csv("data.csv")
data_1000 = data.head(1000)
data_1000.to_csv("data_head_1000.csv")

# %%
data_pandas = pd.DataFrame(data, columns = data.columns)

# %%
data_pandas
# Out:
#                                 0  1                              2
# 0        2023-03-13T07:04:31.079Z  1      {'dataset': 'system.cpu'}  \
# 1        2023-03-13T07:13:31.085Z  1      {'dataset': 'system.cpu'}
# 2        2023-03-13T08:16:41.112Z  1      {'dataset': 'system.cpu'}
# 3        2023-03-13T07:57:51.111Z  1      {'dataset': 'system.cpu'}
# 4        2023-03-13T10:28:11.191Z  1      {'dataset': 'system.cpu'}
# ...                           ... ..                            ...
# 7987576  2023-03-08T06:24:29.991Z  1  {'dataset': 'system.network'}
# 7987577  2023-03-08T06:24:29.991Z  1  {'dataset': 'system.network'}
# 7987578  2023-03-08T06:24:29.991Z  1  {'dataset': 'system.network'}
# 7987579  2023-03-08T06:27:49.991Z  1  {'dataset': 'system.network'}
# 7987580  2023-03-08T06:23:19.991Z  1  {'dataset': 'system.network'}
#
#                             3
# 0        {'name': 'QASERVER'}  \
# 1        {'name': 'QASERVER'}
# 2        {'name': 'QASERVER'}
# 3        {'name': 'QASERVER'}
# 4        {'name': 'QASERVER'}
# ...                       ...
# 7987576   {'name': 'PRUEBAS'}
# 7987577   {'name': 'PRUEBAS'}
# 7987578   {'name': 'PRUEBAS'}
# 7987579   {'name': 'PRUEBAS'}
# 7987580   {'name': 'PRUEBAS'}
#
#                                                          4
# 0        {'cpu': {'cores': 4, 'idle': {'pct': 3.8109}, ...
# 1        {'cpu': {'cores': 4, 'idle': {'pct': 3.7359}, ...
# 2        {'cpu': {'cores': 4, 'idle': {'pct': 3.8563}, ...
# 3        {'cpu': {'cores': 4, 'idle': {'pct': 3.9766}, ...
# 4        {'cpu': {'cores': 4, 'idle': {'pct': 3.8890000...
# ...                                                    ...
# 7987576  {'network': {'out': {'bytes': 0}, 'in': {'byte...
# 7987577                                                NaN
# 7987578  {'network': {'out': {'bytes': 458243923}, 'in'...
# 7987579  {'network': {'out': {'bytes': 0}, 'in': {'byte...
# 7987580  {'network': {'out': {'bytes': 457983373}, 'in'...
#
# [7987581 rows x 5 columns]

# %%
df = pd.DataFrame(data, columns = data.columns)

# %%
df
# Out:
#                                 0  1                              2
# 0        2023-03-13T07:04:31.079Z  1      {'dataset': 'system.cpu'}  \
# 1        2023-03-13T07:13:31.085Z  1      {'dataset': 'system.cpu'}
# 2        2023-03-13T08:16:41.112Z  1      {'dataset': 'system.cpu'}
# 3        2023-03-13T07:57:51.111Z  1      {'dataset': 'system.cpu'}
# 4        2023-03-13T10:28:11.191Z  1      {'dataset': 'system.cpu'}
# ...                           ... ..                            ...
# 7987576  2023-03-08T06:24:29.991Z  1  {'dataset': 'system.network'}
# 7987577  2023-03-08T06:24:29.991Z  1  {'dataset': 'system.network'}
# 7987578  2023-03-08T06:24:29.991Z  1  {'dataset': 'system.network'}
# 7987579  2023-03-08T06:27:49.991Z  1  {'dataset': 'system.network'}
# 7987580  2023-03-08T06:23:19.991Z  1  {'dataset': 'system.network'}
#
#                             3
# 0        {'name': 'QASERVER'}  \
# 1        {'name': 'QASERVER'}
# 2        {'name': 'QASERVER'}
# 3        {'name': 'QASERVER'}
# 4        {'name': 'QASERVER'}
# ...                       ...
# 7987576   {'name': 'PRUEBAS'}
# 7987577   {'name': 'PRUEBAS'}
# 7987578   {'name': 'PRUEBAS'}
# 7987579   {'name': 'PRUEBAS'}
# 7987580   {'name': 'PRUEBAS'}
#
#                                                          4
# 0        {'cpu': {'cores': 4, 'idle': {'pct': 3.8109}, ...
# 1        {'cpu': {'cores': 4, 'idle': {'pct': 3.7359}, ...
# 2        {'cpu': {'cores': 4, 'idle': {'pct': 3.8563}, ...
# 3        {'cpu': {'cores': 4, 'idle': {'pct': 3.9766}, ...
# 4        {'cpu': {'cores': 4, 'idle': {'pct': 3.8890000...
# ...                                                    ...
# 7987576  {'network': {'out': {'bytes': 0}, 'in': {'byte...
# 7987577                                                NaN
# 7987578  {'network': {'out': {'bytes': 458243923}, 'in'...
# 7987579  {'network': {'out': {'bytes': 0}, 'in': {'byte...
# 7987580  {'network': {'out': {'bytes': 457983373}, 'in'...
#
# [7987581 rows x 5 columns]

# %%
data.where(data[""])

# %%
data = pd.read_csv("data.csv")
data.loc[]
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 data = pd.read_csv("data.csv")
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/io/parsers/readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:812, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:873, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:848, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:859, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File ~/.conda/envs/dsc/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:2025, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
data = pd.read_csv("data_head_100.csv")
system = data.system[2]
read_json(system)
# Out:
# {'cpu': {'cores': 4,
#   'idle': {'pct': 3.8563},
#   'user': {'pct': 0.0844},
#   'system': {'pct': 0.059300000000000005}}}
